# %%
from pydataset import data
import pandas as pd

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

grades_df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(grades_df)
# Out:
# pandas.core.frame.DataFrame

# %%
grades_df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
#passing english

# %%
grades_df.english >= 70
grades_df['passing_english'] = grades_df.english >= 70
#mpg['mpg_difference'] = mpg.city

# %%
grades_df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
grades_df.sort_values(by='passing_english') #duplicates are kept
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
grades_df.sort_values(['passing_english', 'name'],ascending=True) 
#duplicates are kept
# Out:
#        name  math  english  reading  passing_english    overall
# 11     Alan    92       62       72            False  65.333333
# 8    Albert    92       62       87            False  70.333333
# 7     Marie    93       63       90            False  72.000000
# 6    Thomas    82       64       81            False  69.666667
# 4       Ada    77       92       98             True  94.000000
# 3     Billy    98       96       88             True  93.333333
# 10    Isaac    92       99       93             True  97.000000
# 1      Jane    88       79       67             True  75.000000
# 5      John    79       76       93             True  81.666667
# 9   Richard    69       80       94             True  84.666667
# 0     Sally    62       85       80             True  83.333333
# 2     Suzie    94       74       95             True  81.000000

# %%
#sort by passing english then grade in english

# %%
grades_df.sort_values(['passing_english', 'english'],ascending = True)
# Out:
#        name  math  english  reading  passing_english    overall
# 8    Albert    92       62       87            False  70.333333
# 11     Alan    92       62       72            False  65.333333
# 7     Marie    93       63       90            False  72.000000
# 6    Thomas    82       64       81            False  69.666667
# 2     Suzie    94       74       95             True  81.000000
# 5      John    79       76       93             True  81.666667
# 1      Jane    88       79       67             True  75.000000
# 9   Richard    69       80       94             True  84.666667
# 0     Sally    62       85       80             True  83.333333
# 4       Ada    77       92       98             True  94.000000
# 3     Billy    98       96       88             True  93.333333
# 10    Isaac    92       99       93             True  97.000000

# %%
grades_df.english >= 70
grades_df['passing_english'] = grades_df.english >= 70

# %%
#Overall grades

# %%
grades_df['overall'] = ((grades_df.english + grades_df.english + grades_df.reading)/3).astype(int)

# %%
grades_df
# Out:
#        name  math  english  reading  passing_english  overall
# 0     Sally    62       85       80             True       83
# 1      Jane    88       79       67             True       75
# 2     Suzie    94       74       95             True       81
# 3     Billy    98       96       88             True       93
# 4       Ada    77       92       98             True       94
# 5      John    79       76       93             True       81
# 6    Thomas    82       64       81            False       69
# 7     Marie    93       63       90            False       72
# 8    Albert    92       62       87            False       70
# 9   Richard    69       80       94             True       84
# 10    Isaac    92       99       93             True       97
# 11     Alan    92       62       72            False       65

# %% [markdown]
# # MPG part

# %%
from pydataset import data
mpg = data('mpg')

# %%
#how many rows and columns
mpg.shape
# Out:
# (234, 11)

# %%
#what are the data types
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg.describe
# Out:
# <bound method NDFrame.describe of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# ...

# %%
#RENAMEs

# %%
mpg = mpg.rename(columns = {'cty':'city','hwy':'highway', 'class':'class_type'})

# %%
mpg = mpg.sort_values(by='highway', ascending=False)
mpg
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 106        honda                civic    1.8  2008    4    auto(l5)   f    25
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
#
#      highway fl  class_type
# ...

# %%
#City vs highway
mpg.city[1]
# Out:
# 18

# %%
mpg_highway = mpg.highway
mpg_highway
# Out:
# 222    44
# 213    44
# 223    41
# 197    37
# 106    36
#        ..
# 66     12
# 60     12
# 127    12
# 70     12
# 55     12
# Name: highway, Length: 234, dtype: int64

# %%
mpg_city = mpg.city
mpg_city
# Out:
# 222    35
# 213    33
# 223    29
# 197    28
# 106    25
#        ..
# 66      9
# 60      9
# 127     9
# 70      9
# 55      9
# Name: city, Length: 234, dtype: int64

# %%
mpg['mpg_difference'] = (mpg.highway - mpg.city)

# %%
mpg_difference.sort_values()
# Out:
# 152     2
# 177     2
# 204     2
# 55      3
# 151     3
#        ..
# 36     11
# 229    11
# 3      11
# 223    12
# 107    12
# Length: 234, dtype: int64

# %%
#NO CARS HAVE HIGHER CITY THAN HIGHWAY, just the hybrids

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway  \
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000
#
#        mpg_difference
# count      234.000000
# mean         6.581197
# std          2.262739
# min          2.000000
# 25%          5.000000
# 50%          7.000000
# 75%          8.000000
# max         12.000000

# %%
mpg.mpg_difference.max()
# Out:
# 12

# %%
mpg[mpg.mpg_difference == mpg.mpg_difference.max()]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
#
#     fl  class_type  mpg_difference
# 223  d  subcompact              12
# 107  c  subcompact              12

# %%
#2008 civic and 1999 beetle have highestt differences

# %%
mpg[mpg['class_type'] == 'compact']
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 213   volkswagen         jetta    1.9  1999    4  manual(m5)   f    33
# 197       toyota       corolla    1.8  2008    4  manual(m5)   f    28
# 198       toyota       corolla    1.8  2008    4    auto(l4)   f    26
# 196       toyota       corolla    1.8  1999    4  manual(m5)   f    26
# 195       toyota       corolla    1.8  1999    4    auto(l4)   f    24
# 189       toyota  camry solara    2.4  2008    4  manual(m5)   f    21
# 3           audi            a4    2.0  2008    4  manual(m6)   f    20
# 190       toyota  camry solara    2.4  2008    4    auto(s5)   f    22
# 194       toyota       corolla    1.8  1999    4    auto(l3)   f    24
# 4           audi            a4    2.0  2008    4    auto(av)   f    21
# 208   volkswagen           gti    2.0  1999    4  manual(m5)   f    21
# 2           audi            a4    1.8  1999    4  manual(m5)   f    21
# ...

# %%
compacts = mpg[mpg['class_type'] == 'compact']

# %%
compacts[(compacts.highway == compacts.highway.max())]
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#     class_type  mpg_difference
# 213    compact              11

# %%
models = mpg.model

# %%
models = list(models)

# %%
#which compact car has the worst and best highway mileage
car_class = mpg.class_type

# %%
car_class = list(car_class)

# %%
#car_class

# %%
car_class[0]
# Out:
# 'subcompact'

# %%
hwy_miles = mpg.highway

# %%
hwy_miles = list(hwy_miles)

# %%
#hwy_miles
hwy_miles[0]
# Out:
# 44

# %% [markdown]
# # checking if compact and adding to dict

# %%
car_dict = {'id_number':[],'class':[],'miles':[],'model':[]}
x=0
for i in car_class:
    #print(i)
    if i == 'compact':
    #car_dict.update({'id_number':x,'class':car_class[x],'miles':hwy_miles[x]})
        car_dict['id_number'].append(x)
        car_dict['class'].append(car_class[x])
        car_dict['miles'].append(hwy_miles[x])
        car_dict['model'].append(models[x])
        x += 1
    else:
           x+=1
    if x > 300:
        break
        
#car_dict
print(car_dict['model'][0] + ' ' + str(car_dict['id_number'][0]))
print(car_dict['model'][1] + ' ' + str(car_dict['id_number'][1]))
print(car_dict['model'][-1] + ' ' + str(car_dict['id_number'][-1])) 
print(car_dict['model'][-2] + ' ' + str(car_dict['id_number'][-2]))
# Out:
# jetta 1
# corolla 3
# jetta 129
# gti 119

# %%
#now add mileage
#x=1
#for i in car_dict:
#    print(i)
#    car_dict[keys(x)] = hwy_miles[x]
#    x += 1
#    if x > 10:
#        break
        
#car_dict

# %%
#compact_cars = {}
#x=1
#while x < 3:    
#    if car_class[x] == 'compact':
#        compact_cars.append(car_class[x])
#        print(compact_cars)
#        x+=1
#        if x > 10:
#            break

# %%
mpg['average_mileage'] = (mpg.city + mpg.highway)/2

# %%
average_mileage
# Out:
# 222    39.5
# 213    38.5
# 223    35.0
# 197    32.5
# 106    30.5
#        ...
# 66     10.5
# 60     10.5
# 127    10.5
# 70     10.5
# 55     10.5
# Length: 234, dtype: float64

# %%
average_mileage[222]
# Out:
# 39.5

# %%
average_mileage[70]
# Out:
# 10.5

# %%
mpg.manufacturer[1]
# Out:
# 'audi'

# %%
average_mileage[1]
# Out:
# 23.5

# %%
dodges = mpg[mpg.manufacturer == 'dodge']

# %%
dodges[dodges.average_mileage == dodges.average_mileage.max()]
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl class_type  mpg_difference  average_mileage
# 38  r    minivan               6             21.0

# %%
dodges[dodges.average_mileage == dodges.average_mileage.min()]
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
#
#     highway fl class_type  mpg_difference  average_mileage
# 66       12  e     pickup               3             10.5
# 60       12  e        suv               3             10.5
# 70       12  e     pickup               3             10.5
# 55       12  e     pickup               3             10.5

# %%
q = 0
high_miler = ''
highest_mpg = 0
while q < 234:
    
    
    #print('q = ' + str(q))
    #print(mpg.manufacturer[q+1])
    checksum = str(mpg.manufacturer[q+1])
    if checksum == 'dodge':
        if average_mileage[q+1] > highest_mpg:
            highest_mpg = average_mileage[q+1]
            high_miler = str(mpg.manufacturer[q+1])
            indy = mpg.index[q+1]
            q +=1
          #  print('one added')
        else:
     #       print('nope')
            q+=1
    else:
        q += 1
   # print('nothing at all')
    if q > 300:
        break

print(mpg.iloc[indy])
# Out:
# manufacturer             chevrolet
# model           c1500 suburban 2wd
# displ                          5.3
# year                          2008
# cyl                              8
# trans                     auto(l4)
# drv                              r
# city                            11
# highway                         15
# fl                               e
# class_type                     suv
# Name: 20, dtype: object

# %%
q = 0
high_miler = ''
highest_mpg = 0
while q < 234:
    
    
    #print('q = ' + str(q))
    #print(mpg.manufacturer[q+1])
    checksum = str(mpg.manufacturer[q+1])
    if checksum == 'dodge':
        if average_mileage[q+1] < highest_mpg:
            highest_mpg = average_mileage[q+1]
            high_miler = str(mpg.manufacturer[q+1])
            indy = mpg.index[q+1]
            q +=1
          #  print('one added')
        else:
     #       print('nope')
            q+=1
    else:
        q += 1
   # print('nothing at all')
    if q > 300:
        break

print(mpg.iloc[indy])
# Out:
# manufacturer             chevrolet
# model           c1500 suburban 2wd
# displ                          5.3
# year                          2008
# cyl                              8
# trans                     auto(l4)
# drv                              r
# city                            11
# highway                         15
# fl                               e
# class_type                     suv
# Name: 20, dtype: object

# %%
animals = data('Mammals')

# %%
#animals.shape 4 columns, 107 rows

# %%
animals.describe
# Out:
# <bound method NDFrame.describe of        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
#datatypes are float, float, bool, bool

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
animals[animals.speed == animals.speed.max()].weight
# Out:
# 53    55.0
# Name: weight, dtype: float64

# %%
animals.iloc[53]
# Out:
# weight       45.0
# speed        50.0
# hoppers     False
# specials    False
# Name: 54, dtype: object

# %%
animals.specials.sum()
# Out:
# 10

# %%
len(animals)
# Out:
# 107

# %%
10/107 #percentage of animals that are special
# Out:
# 0.09345794392523364

# %%
#how many hoppers above median speed? what percentage is it?

# %%
#animals.hoppers
#animals.speed.median()

# %%
numerator = len(animals[(animals.hoppers == True) & (animals.speed > animals.speed.median())])

# %%
round((numerator / len(animals))*100, 2)
# Out:
# 6.54
